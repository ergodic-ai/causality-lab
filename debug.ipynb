# %%
from server.utils import (
    generate_random_data,
    generate_retention_data,
    graph_object_to_edges,
    initialize_fci,
    run_cd,
    edges_to_graph_object,
)

df = generate_retention_data()

# %%
model = initialize_fci(df)
_ = run_cd(model)
# Out:
# Removing edge discount -- engagement based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'discount', 'node_j': 'engagement', 'cond_set': []}
# Removing edge discount -- stale_items based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'discount', 'node_j': 'stale_items', 'cond_set': []}
# Removing edge discount -- new_items based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'discount', 'node_j': 'new_items', 'cond_set': []}
# Removing edge engagement -- distance based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'engagement', 'node_j': 'distance', 'cond_set': []}
# Removing edge engagement -- traffic based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'engagement', 'node_j': 'traffic', 'cond_set': []}
# Removing edge engagement -- service_problems based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'engagement', 'node_j': 'service_problems', 'cond_set': []}
# Removing edge distance -- traffic based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'distance', 'node_j': 'traffic', 'cond_set': []}
# Removing edge distance -- stale_items based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'distance', 'node_j': 'stale_items', 'cond_set': []}
# Removing edge distance -- new_items based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'distance', 'node_j': 'new_items', 'cond_set': []}
# Removing edge traffic -- stale_items based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'traffic', 'node_j': 'stale_items', 'cond_set': []}
# Removing edge traffic -- new_items based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'traffic', 'node_j': 'new_items', 'cond_set': []}
# Removing edge stale_items -- service_problems based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'stale_items', 'node_j': 'service_problems', 'cond_set': []}
# Removing edge stale_items -- new_items based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'stale_items', 'node_j': 'new_items', 'cond_set': []}
# Removing edge service_problems -- new_items based on the conditioning set: (){'action': 'remove_edge', 'node_i': 'service_problems', 'node_j': 'new_items', 'cond_set': []}
# Removing edge discount -- distance based on the conditioning set: ('service_problems',){'action': 'remove_edge', 'node_i': 'discount', 'node_j': 'distance', 'cond_set': ['service_problems']}
# Removing edge discount -- traffic based on the conditioning set: ('service_problems',){'action': 'remove_edge', 'node_i': 'discount', 'node_j': 'traffic', 'cond_set': ['service_problems']}
# Removing edge distance -- retention based on the conditioning set: ('service_problems',){'action': 'remove_edge', 'node_i': 'distance', 'node_j': 'retention', 'cond_set': ['service_problems']}
# Removing edge traffic -- retention based on the conditioning set: ('service_problems',){'action': 'remove_edge', 'node_i': 'traffic', 'node_j': 'retention', 'cond_set': ['service_problems']}
# Removing edge retention -- stale_items based on the conditioning set: ('engagement',){'action': 'remove_edge', 'node_i': 'retention', 'node_j': 'stale_items', 'cond_set': ['engagement']}
# Removing edge retention -- new_items based on the conditioning set: ('engagement',){'action': 'remove_edge', 'node_i': 'retention', 'node_j': 'new_items', 'cond_set': ['engagement']}
# Iteration
# Iteration
# Oriented v-structure: node_a *--> node_b <--* node_c{'action': 'orient_v_structure', 'node_a': 'stale_items', 'node_b': 'engagement', 'node_c': 'new_items'}
# Oriented v-structure: node_a *--> node_b <--* node_c{'action': 'orient_v_structure', 'node_a': 'discount', 'node_b': 'retention', 'node_c': 'engagement'}
# Oriented v-structure: node_a *--> node_b <--* node_c{'action': 'orient_v_structure', 'node_a': 'service_problems', 'node_b': 'retention', 'node_c': 'engagement'}
# Oriented v-structure: node_a *--> node_b <--* node_c{'action': 'orient_v_structure', 'node_a': 'distance', 'node_b': 'service_problems', 'node_c': 'traffic'}
# Iteration
# Iteration
# Oriented v-structure: node_a *--> node_b <--* node_c{'action': 'orient_v_structure', 'node_a': 'stale_items', 'node_b': 'engagement', 'node_c': 'new_items'}
# Oriented v-structure: node_a *--> node_b <--* node_c{'action': 'orient_v_structure', 'node_a': 'discount', 'node_b': 'retention', 'node_c': 'engagement'}
# Oriented v-structure: node_a *--> node_b <--* node_c{'action': 'orient_v_structure', 'node_a': 'service_problems', 'node_b': 'retention', 'node_c': 'engagement'}
# Oriented v-structure: node_a *--> node_b <--* node_c{'action': 'orient_v_structure', 'node_a': 'distance', 'node_b': 'service_problems', 'node_c': 'traffic'}
# Orienting edges node_a *--> node_b ---> node_c{'action': 'orient_edge_1', 'node_a': 'stale_items', 'node_b': 'engagement', 'node_c': 'retention'}
# Orienting edges node_a *--> node_b ---> node_c{'action': 'orient_edge_1', 'node_a': 'new_items', 'node_b': 'engagement', 'node_c': 'retention'}
# Orienting edges node_a *--> node_b ---> node_c{'action': 'orient_edge_1', 'node_a': 'distance', 'node_b': 'service_problems', 'node_c': 'discount'}
# Orienting edges node_a *--> node_b ---> node_c{'action': 'orient_edge_1', 'node_a': 'distance', 'node_b': 'service_problems', 'node_c': 'retention'}
# Orienting edges node_a *--> node_b ---> node_c{'action': 'orient_edge_1', 'node_a': 'traffic', 'node_b': 'service_problems', 'node_c': 'discount'}
# Orienting edges node_a *--> node_b ---> node_c{'action': 'orient_edge_1', 'node_a': 'traffic', 'node_b': 'service_problems', 'node_c': 'retention'}
# Iteration
# Iteration
# [{'id': 'discount-retention', 'source': 'discount', 'target': 'retention', 'data': {'edge_type': 'partially_known', 'relationship': 1}}, {'id': 'service_problems-discount', 'source': 'service_problems', 'target': 'discount', 'data': {'edge_type': 'directed', 'relationship': 3}}, {'id': 'distance-service_problems', 'source': 'distance', 'target': 'service_problems', 'data': {'edge_type': 'partially_known', 'relationship': 1}}, {'id': 'new_items-engagement', 'source': 'new_items', 'target': 'engagement', 'data': {'edge_type': 'partially_known', 'relationship': 1}}, {'id': 'engagement-retention', 'source': 'engagement', 'target': 'retention', 'data': {'edge_type': 'directed', 'relationship': 3}}, {'id': 'stale_items-engagement', 'source': 'stale_items', 'target': 'engagement', 'data': {'edge_type': 'partially_known', 'relationship': 1}}, {'id': 'service_problems-retention', 'source': 'service_problems', 'target': 'retention', 'data': {'edge_type': 'directed', 'relationship': 3}}, {'id': 'traffic-service_problems', 'source': 'traffic', 'target': 'service_problems', 'data': {'edge_type': 'partially_known', 'relationship': 1}}]

# %%
from plot_utils.draw_graph import draw_graph

_ = draw_graph(model.graph)
